# %% [markdown]
# # Milestone 1
# Abdul Haris
#
# # Pendahuluan
# Ingin eksplorasi data berita kejadian di Indonesia menggunakan dataset berita GDELT.

# %% [markdown]
# # Eksplorasi Data
# ## Download
# Data ini bisa diproses melalui cloud atau lokal. Dalam project ini, proses data akan dilakukan secara lokal sehingga perlu didownload data GDELT terlebih dahulu.
#
# Terdapat beberapa cara untuk mendownload data GDELT:
# 1. Menggunakan script
# 2. Menggunakan layanan GKG Record Exporter
# 3. Menggunakan layanan Event Record Exporter

# %% [markdown]
# ## Buka Koneksi MySQL lokal
# Silakan buka program SQL favorit anda (HeidiSQL, Laragon), lalu buat database dengan nama 'news'.

# %%
import pymysql
import pandas as pd
from sqlalchemy import create_engine

host = 'localhost'
port = '3306'
username = 'root'
password = ''
database = 'news'
# database = 'classicmodels'

# Create Connection to Database
engine = create_engine('mysql+pymysql://'+username+':'+password+'@'+host+':'+port+'/'+database)
# '''engine = create_engine('mysql+pymysql://root: @localhost:3306/academic')'''

def run(sql):
    df = pd.read_sql_query(sql, engine)
    return df

# %% [markdown]
# ## 2. Menggunakan layanan GKG Record Exporter
# The GKG Record Exporter allows you to rapidly export small subsets of data from the GDELT Global Knowledge Graph (GKG) that match your search criteria. You simply specify a set of person or organization names, locations, or Global Knowledge Graph Themes, along with an optional date range, and the system will automatically search the entire Global Knowledge Graph for all matching entries and output the list of matching GKG records and a list of all source articles providing the matching records. While you will still need programming experience to be able to use these exported results further, this tool allows you to rapidly export small subsets of data from the complete massive GKG database. Currently searches will only return the first 200,000 matching results. Your results will be emailed to you when complete, usually within 10 minutes, depending on server load.
#
# ### Download
# Disini saya mendownload data GKG Record dengan rentang tanggal 1 Januari 2018 sampai 31 Oktober 2018 dengan keyword pencarian diskusi "Indonesia".

# %%
from os import listdir
from os.path import isfile, join
folder_id = './Data/'
files = [f for f in listdir(folder_id) if isfile(join(folder_id, f))]
print(files)
# Out:
# ['20181106005702.5386.gkg.txt', 'Credit.csv']

# %% [markdown]
# ### Check The Data

# %%
from os import listdir
from os.path import isfile, join
folder_id = './Data/'
files = [f for f in listdir(folder_id) if isfile(join(folder_id, f))]
print(files[0])
# Out:
# 20181106005702.5386.gkg.txt

# %%
# Open first file for sanity check
df_awal = pd.read_csv(folder_id + files[0],sep="\t")

# %%
df_awal.head()
# Out:
#        Date  NumArticles                                             Counts  \
# 0  20180101            1                                                NaN
# 1  20180101            1                                                NaN
# 2  20180101            1                                                NaN
# 3  20180101            1                                                NaN
# 4  20180101            1  AFFECT#51##4#Kalimantan, Indonesia (General), ...
#
#                                               Themes  \
# 0  TAX_ETHNICITY;TAX_ETHNICITY_INDONESIAN;TAX_WOR...
# 1  TAX_RELIGION;TAX_RELIGION_SHARIA;UNGP_FORESTS_...
# 2  ECON_TAXATION;USPEC_POLICY1;EPU_POLICY;EPU_POL...
# 3  TAX_FNCACT;TAX_FNCACT_MINISTER;LEADER;TAX_FNCA...
# 4  NATURAL_DISASTER;NATURAL_DISASTER_DROWN;MARITI...
#
#                                            Locations  \
# 0  1#Indonesia#ID#ID#-5#120#ID;4#Jakarta, Jakarta...
# 1                        1#Indonesia#ID#ID#-5#120#ID
# 2  1#Indonesia#ID#ID#-5#120#ID;4#Jakarta, Jakarta...
# 3  4#Tuas, Singapore (General), Singapore#SN#SN00...
# 4  4#Tarakan, Kalimantan Timur, Indonesia#ID#ID14...
#
#                          Persons  \
# 0  anies baswedan;muhammad nasir
# 1          ahmad soekro tratmono
# 2                            NaN
# 3     donald trump;halimah yacob
# 4                            NaN
#
#                                        Organizations  \
# 0                                                NaN
# 1                                                NaN
# 2                               freeport mcmoran inc
# 3  nanyang girl high school;singapore malayalee a...
# 4                                                NaN
#
#                                             ToneData  \
# 0  6.51340996168582,7.66283524904215,1.1494252873...
# 1  0.315457413249211,1.89274447949527,1.577287066...
# 2  -2.04918032786885,1.63934426229508,3.688524590...
# 3  1.5647226173542,3.62731152204836,2.06258890469...
# 4  -2.9940119760479,2.09580838323353,5.0898203592...
#
#                      CAMEOEvents                    Sources  \
# 0                      719036954                coconuts.co
# 1                            NaN  indonesia-investments.com
# 2                            NaN        customstoday.com.pk
# 3  719030357,719031298,719031301           straitstimes.com
# 4            719080657,719142399            dailymail.co.uk
#
#                                           SourceURLs
# 0  https://coconuts.co/jakarta/news/mass-wedding-...
# 1  https://www.indonesia-investments.com/news/tod...
# 2  http://www.customstoday.com.pk/despite-tax-sho...
# 3  http://www.straitstimes.com/singapore/a-strong...
# 4  http://www.dailymail.co.uk/news/article-522596...

# %%
df_awal.shape
# Out:
# (200001, 11)

# %% [markdown]
# Berikut penjelasan header dari data GKG yang didapat:
# ![title](gkg.png)

# %%
# for i in df_awal["Themes"]:
#     print(i)
ukuran = df_awal["SourceURLs"].str.len().max()
print(ukuran)
# Out:
# 38165

# %% [markdown]
# Create table "gdelt_gkg" terlebih dahulu di database jika belum ada.

# %%
engine.execute("""
CREATE TABLE IF NOT EXISTS 
gdelt_gkg (Date INT,
	NumArticles INT,
	Counts TEXT,
	Themes TEXT,
	Locations TEXT,
	Persons TEXT,
	Organizations TEXT,
	ToneData VARCHAR(256),
	CAMEOEvents TEXT,
	Sources TEXT,
	SourceURLs TEXT )
""")

# %% [markdown]
# ## Simpan ke MySQL

# %%
df_awal.columns
df_awal.to_sql(name='gdelt_gkg', con = engine, if_exists='append', index=False)

# %% [markdown]
# ## Tranformasi Data
#
# ### Cek Awal
# Setelah data tersimpan secara sukses di MySQL, kita melakukan eksplorasi sederhana. Langkah pertama yang perlu dilakukan adalah melakukan filter artikel yang benar-benar sesuai dengan Indonesia dengan sumber media asing. Dengan asumsi judul berita dimuat dalam URL artikel, maka dilakukan filter kolom 'SOURCEURL' dengan menggunakan kata kunci yang berhubungan dengan topik Indonesia. Sejauh ini ada beberapa kata kunci adalah sebagai berikut:
#
# - Indonesia
# - Java
# - Jakarta
# - Bali
# - Lombok

# %%
# SQL query to look for keyword in SOURCEURL
data_indonesia = run("""
SELECT 
    * 
FROM 
    gdelt_gkg
WHERE
    SourceURLs LIKE '%%indonesia%%' OR
    SourceURLs LIKE '%%java%%' OR
    SourceURLs LIKE '%%bali%%' OR    
    SourceURLs LIKE '%%lombok%%' OR  
    SourceURLs LIKE '%%jakarta%%'
    """)

# %%
print(data_indonesia.shape)
data_indonesia.sample(25)
# Out:
# (43503, 11)
#            Date  NumArticles  \
# 29112  20180427            1
# 21794  20180331            1
# 15199  20180301            1
# 3889   20180117            1
# 32314  20180513            1
# 31218  20180509            1
# 12218  20180219            1
# 25108  20180412            1
# 39846  20180601            1
# 35632  20180516            1
# 29969  20180503            1
# 8985   20180206            1
# 28063  20180424            1
# 42820  20180618            1
# 124    20180101            1
# 12811  20180220            1
# 33274  20180513            2
# 41949  20180613            1
# 18081  20180313            1
# 23075  20180405            1
# 40259  20180604            1
# 27186  20180420            7
# 23110  20180405            1
# 10634  20180212            1
# 18127  20180313            1
#
#                                                   Counts  \
# 29112                                               None
# 21794                                               None
# 15199  SEIZE#200#m yacht#3#Hollywood, California, Uni...
# 3889               KILL#60##1#Indonesia#ID#ID#-5#120#ID;
# 32314  KILL#9##1#Indonesia#ID#ID#-5#120#ID;WOUND#24##...
# 31218                                               None
# 12218                                               None
# 25108                                               None
# 39846                                               None
# 35632                                               None
# 29969                                               None
# 8985   ARREST#3##1#Indonesia#ID#ID#-5#120#ID;SOC_GENE...
# 28063  KILL#11##4#Kabul, Kabol, Afghanistan#AF#AF13#3...
# 42820                                               None
# 124    KILL#8##1#Indonesia#ID#ID#-5#120#ID;CRISISLEX_...
# 12811                                               None
# 33274  KILL#6#bombers#4#Surabaya, Jawa Timur, Indones...
# 41949  KILL#13##4#Makassar, (Id20), Indonesia#ID#ID20...
# 18081                                               None
# 23075                                               None
# 40259                                               None
# 27186         PROTEST#2000##1#Indonesia#ID#ID#-5#120#ID;
# 23110  PROTEST#5##4#Ciputat, Jawa Barat, Indonesia#ID...
# 10634                                               None
# 18127                                               None
#
#                                                   Themes  \
# 29112  LEADER;TAX_FNCACT;TAX_FNCACT_PRESIDENT;USPEC_P...
# 21794  NATURAL_DISASTER;NATURAL_DISASTER_EARTHQUAKE;C...
# 15199  MARITIME;SEIZE;CORRUPTION;WB_2019_ANTI_CORRUPT...
# 3889   TAX_ETHNICITY;TAX_ETHNICITY_INDONESIAN;TAX_WOR...
# 32314  SOC_SUICIDE;CRISISLEX_CRISISLEXREC;TERROR;SUIC...
# 31218  TAX_ETHNICITY;TAX_ETHNICITY_DUTCH;TAX_WORLDLAN...
# 12218  WB_678_DIGITAL_GOVERNMENT;WB_694_BROADCAST_AND...
# 25108                                            LEADER;
# 39846                          MANMADE_DISASTER_IMPLIED;
# 35632  SOC_POINTSOFINTEREST;SOC_POINTSOFINTEREST_AIRP...
# 29969  ENV_BIOFUEL;WB_532_BIOFUELS_ENERGY;WB_507_ENER...
# 8985   TAX_ETHNICITY;TAX_ETHNICITY_INDONESIAN;TAX_WOR...
# 28063  TAX_ETHNICITY;TAX_ETHNICITY_INDONESIAN;TAX_WOR...
# 42820  TOURISM;WB_825_TOURISM;WB_1921_PRIVATE_SECTOR_...
# 124    KILL;CRISISLEX_CRISISLEXREC;CRISISLEX_T02_INJU...
# 12811  NATURAL_DISASTER;NATURAL_DISASTER_ERUPTION;WB_...
# 33274  SOC_SUICIDE;TERROR;SUICIDE_ATTACK;TAX_WEAPONS;...
# 41949  KILL;CRISISLEX_CRISISLEXREC;CRISISLEX_T02_INJU...
# 18081  TAX_FNCACT;TAX_FNCACT_ARTISTS;DISABILITY;WB_14...
# 23075  TAX_FNCACT;TAX_FNCACT_OMBUDSMAN;WB_696_PUBLIC_...
# 40259  WB_286_TELECOMMUNICATIONS_AND_BROADBAND_ACCESS...
# 27186  TAX_WORLDLANGUAGES;TAX_WORLDLANGUAGES_BANDA;TA...
# 23110  TAX_WORLDMAMMALS;TAX_WORLDMAMMALS_SEAL;WB_135_...
# 10634  ENV_FISHERY;TAX_FNCACT;TAX_FNCACT_MINISTER;MAR...
# 18127  USPEC_POLICY1;EPU_ECONOMY;EPU_ECONOMY_HISTORIC...
#
#                                                Locations  \
# 29112  1#Vietnam, Republic Of#VM#VM#16.166667#107.833...
# 21794                        1#Indonesia#ID#ID#-5#120#ID
# 15199  1#Australia#AS#AS#-25#135#AS;1#Malaysia#MY#MY#...
# 3889                         1#Indonesia#ID#ID#-5#120#ID
# 32314  4#Diponegoro, Jawa Timur, Indonesia#ID#ID08#-7...
# 31218  1#Japan#JA#JA#36#138#JA;4#Merdeka, Nusa Tengga...
# 12218  1#Indonesia#ID#ID#-5#120#ID;4#Jakarta, Jakarta...
# 25108  4#Denpasar, Bali, Indonesia#ID#ID02#-8.65#115....
# 39846  1#Australia#AS#AS#-25#135#AS;4#Lombok Strait, ...
# 35632  4#Halim Perdanakusuma, Jakarta Raya, Indonesia...
# 29969                        1#Indonesia#ID#ID#-5#120#ID
# 8985   4#Bali, Jawa Timur, Indonesia#ID#ID08#-7.1046#...
# 28063  2#New York, United States#US#USNY#42.1497#-74....
# 42820  4#Bali, Jawa Timur, Indonesia#ID#ID08#-7.1046#...
# 124    4#Tarakan, Kalimantan Timur, Indonesia#ID#ID14...
# 12811  1#Indonesia#ID#ID#-5#120#ID;4#Lhokseumawe, Ace...
# 33274  4#Diponegoro, Jawa Timur, Indonesia#ID#ID08#-7...
# 41949  4#Makassar, (Id20), Indonesia#ID#ID20#-5.14#11...
# 18081  1#Indonesia#ID#ID#-5#120#ID;4#Jakarta, Jakarta...
# 23075  5#West Java, Jawa Barat, Indonesia#ID#ID30#-6....
# 40259  1#Mexico#MX#MX#23#-102#MX;1#Bangladesh#BG#BG#2...
# 27186                        1#Indonesia#ID#ID#-5#120#ID
# 23110  4#Pamulang, Jawa Barat, Indonesia#ID#ID30#-6.3...
# 10634  4#Jakarta, Jakarta Raya, Indonesia#ID#ID04#-6....
# 18127  1#China#CH#CH#35#105#CH;1#Indonesia#ID#ID#-5#1...
#
#                                                  Persons  \
# 29112  nguyen xuan phuc;alan peter s cayetano;mar yap...
# 21794                                               None
# 15199  winston churchill;miranda kerr;lindsay lohan;m...
# 3889                                                None
# 32314                               frans barung mangera
# 31218       lucas martin sarkies;surabayahotel majapahit
# 12218                           nick macfie;tabita diela
# 25108                                        jusuf kalla
# 39846  michel bourez;phil toledo;steph gilmore;griff ...
# 35632  majalengka-westjava kertajati;bandara internas...
# 29969                                               None
# 8985                           allah akbar;suryadi masud
# 28063  setya novanto;donald trump;jacinda ardern;joko...
# 42820                                       i gde pitana
# 124                                     manangap djumala
# 12811                      mount sinabung;kamil syahbana
# 33274  gormar gultom;nahdlatul ulama;jemaah anshorut ...
# 41949                        aris bachtiar;barrang lompo
# 18081          ananda sukarlan;yayasan daya pelita kasih
# 23075                       yusran uccang;dominikus dalu
# 40259                                               None
# 27186                                         banda aceh
# 23110  hafids fidon;cinere serpong jaya;m irsan setia...
# 10634                                               None
# 18127   vincent bremmer;foulger underwood;miguel latorre
#
#                                            Organizations  \
# 29112  department of foreign affairs;association of s...
# 21794                    earthquake notification service
# 15199                                               None
# 3889                                                None
# 32314  santa maria roman catholic church;pantekosta c...
# 31218  hotel freedom hotel majapahit;raffles hotel;ho...
# 12218  google;facebook;facebook inc whatsapp messenge...
# 25108  bali nusa dua convention center;international ...
# 39846                                               None
# 35632  mutia fauzia kertajati international airport i...
# 29969                                    research report
# 8985             jakarta district court;associated press
# 28063  corruption eradication commission;associated p...
# 42820  market development;indonesian ministry of tour...
# 124                                                 None
# 12811                                   indonesia center
# 33274  santa maria roman catholic church;indonesian c...
# 41949                                           facebook
# 18081     art brut indonesia foundation;js luwansa hotel
# 23075  jakarta education agency;java education agency...
# 40259  google;os stores;dent wireless company;united ...
# 27186                associated press;human rights watch
# 23110                                               None
# 10634                                   maritime affairs
# 18127  international expansion;international expansio...
#
#                                                 ToneData  \
# 29112  0.213675213675214,1.70940170940171,1.495726495...
# 21794  -0.886262924667651,0.295420974889217,1.1816838...
# 15199  -0.48076923076923,3.84615384615385,4.326923076...
# 3889   -3.33333333333333,2.22222222222222,5.555555555...
# 32314               -10.625,0.625,11.25,11.875,23.4375,0
# 31218  0,3.24574961360124,3.24574961360124,6.49149922...
# 12218  -3.94088669950739,0.164203612479475,4.10509031...
# 25108  2.29357798165138,2.29357798165138,0,2.29357798...
# 39846  0,1.75695461200586,1.75695461200586,3.51390922...
# 35632  1.03806228373702,1.03806228373702,0,1.03806228...
# 29969  3.16091954022989,4.02298850574713,0.8620689655...
# 8985   -12.2699386503067,1.22699386503067,13.49693251...
# 28063  -6.96821515892421,2.32273838630807,9.290953545...
# 42820  3.77358490566038,5.89622641509434,2.1226415094...
# 124    -2.20994475138122,2.76243093922652,4.972375690...
# 12811  -3.18471337579618,1.91082802547771,5.095541401...
# 33274  -8.75816993464052,0.392156862745098,9.15032679...
# 41949  -1.61290322580645,2.1505376344086,3.7634408602...
# 18081  -1.66666666666667,3.33333333333333,5,8.3333333...
# 23075  -3.57142857142857,0,3.57142857142857,3.5714285...
# 40259  -1.63487738419619,1.49863760217984,3.133514986...
# 27186  -5.38243626062323,1.41643059490085,6.798866855...
# 23110  -4.21455938697318,0,4.21455938697318,4.2145593...
# 10634  0.763358778625954,4.19847328244275,3.435114503...
# 18127  3.1523642732049,3.85288966725044,0.70052539404...
#
#                                              CAMEOEvents  \
# 29112  751280109,751150930,751136186,751209646,751280...
# 21794                                               None
# 15199  734990881,734990910,734990911,734991563,734991...
# 3889                                                None
# 32314  755487937,755474126,755480659,755468413,755480...
# 31218                                               None
# 12218                                               None
# 25108  746858359,746858361,746858370,746858371,746859...
# 39846                                          760947153
# 35632                                               None
# 29969                                               None
# 8985                       728560577,728560579,728561391
# 28063                                               None
# 42820                                          765029720
# 124                                  719078020,719078450
# 12811                                               None
# 33274  755487935,755505193,755539481,755539482,755539...
# 41949  763940509,763887762,763940536,763940542,763941...
# 18081                                               None
# 23075                                               None
# 40259                                               None
# 27186  749287641,749287691,749288492,749288494,749288...
# 23110                                          744939614
# 10634                                               None
# 18127                                               None
#
#                                                  Sources  \
# 29112                                   bworldonline.com
# 21794                            earthquakenewstoday.com
# 15199                                      express.co.uk
# 3889                                       aljazeera.com
# 32314                                     vancourier.com
# 31218                                 indonesiaexpat.biz
# 12218                                          yahoo.com
# 25108                                         tralac.org
# 39846                                         surfer.com
# 35632                                 thejakartapost.com
# 29969                                    tokenbeasts.com
# 8985                                  washingtonpost.com
# 28063                              voiceofalexandria.com
# 42820                                  balidiscovery.com
# 124                                          voanews.com
# 12811                                        gazette.com
# 33274                   thedailytimes.com;times-news.com
# 41949                              freemalaysiatoday.com
# 18081                                 thejakartapost.com
# 23075                                 thejakartapost.com
# 40259                                cryptoglobalist.com
# 27186  heraldcourier.com;nptelegraph.com;journalstar....
# 23110                                 thejakartapost.com
# 10634                                    jakartaglobe.id
# 18127                                   prnewswire.co.uk
#
#                                               SourceURLs
# 29112  http://bworldonline.com/duterte-to-hold-bilate...
# 21794  http://www.earthquakenewstoday.com/2018/03/31/...
# 15199  https://www.express.co.uk/news/uk/925704/Yacht...
# 3889   http://www.aljazeera.com/news/2018/01/indonesi...
# 32314  http://www.vancourier.com/9-dead-40-wounded-as...
# 31218  http://indonesiaexpat.biz/travel/hotel-majapah...
# 12218  https://au.news.yahoo.com/a/39222774/new-indon...
# 25108  https://www.tralac.org/news/article/12926-indo...
# 39846  https://www.surfer.com/features/bali-pro-indo-...
# 35632  http://www.thejakartapost.com/travel/2018/05/1...
# 29969  https://tokenbeasts.com/indonesia-biofuels-cat...
# 8985   https://www.washingtonpost.com/world/asia_paci...
# 28063  http://www.voiceofalexandria.com/news/world/co...
# 42820  http://www.balidiscovery.com/news/enhancing-th...
# 124    https://www.voanews.com/a/indonesia-boat-accid...
# 12811  http://gazette.com/volcanic-blast-reshaped-sum...
# 33274  https://www.thedailytimes.com/news/nation_worl...
# 41949  http://www.freemalaysiatoday.com/category/worl...
# 18081  http://www.thejakartapost.com/news/2018/03/14/...
# 23075  http://www.thejakartapost.com/news/2018/04/04/...
# 40259  https://www.cryptoglobalist.com/2018/06/04/den...
# 27186  http://www.heraldcourier.com/news/indonesia-s-...
# 23110  http://www.thejakartapost.com/news/2018/04/05/...
# 10634  http://jakartaglobe.id/business-international/...
# 18127  http://www.prnewswire.co.uk/news-releases/vist...

# %%
df_source = df_awal.dropna(subset=['Sources'])
list_link = []

# f = open('Data\Sources.txt','w')

for index, row in df_source.iterrows():
    splitted = row['Sources'].split(";")
    for i in splitted:
#         f.write(i)
        list_link.append(i)
#     URL = row['SourceURLs'].split('<UDIV>')
    
data_link = pd.Series(list_link)

# Count by its occurences
data_link_count = data_link.value_counts()
data_link_count
# f.close()
# Out:
# thejakartapost.com               6491
# reuters.com                      4781
# en.tempo.co                      4121
# ianslive.in                      2755
# msn.com                          2746
# openpr.com                       2409
# yahoo.com                        2222
# tvguide.co.uk                    2208
# 4-traders.com                    2167
# philstar.com                     2098
# nzcity.co.nz                     1854
# antaranews.com                   1792
# indiatimes.com                   1708
# business-standard.com            1696
# republika.co.id                  1551
# jakartaglobe.id                  1548
# thestar.com.my                   1391
# straitstimes.com                 1365
# businesstimes.com.sg             1363
# theedgemarkets.com               1332
# themalaymailonline.com           1308
# dailymail.co.uk                  1305
# netralnews.com                   1049
# btvi.in                           945
# iheart.com                        936
# bangkokpost.com                   920
# military-technologies.net         902
# pr-inside.com                     886
# channelnewsasia.com               840
# prnewswire.com                    834
#                                  ...
# wvi.org                             1
# msstate.edu                         1
# thelocal.it                         1
# capx.co                             1
# lajollalight.com                    1
# thedailynewsonline.com              1
# beniciaindependent.com              1
# airwise.com                         1
# thecarousel.com                     1
# terrorism-info.org.il               1
# highlandmirror.com                  1
# bcg.com                             1
# dungogchronicle.com.au              1
# ciwm-journal.co.uk                  1
# adirondackdailyenterprise.com       1
# charitynavigator.org                1
# afl.com.au                          1
# vmagazine.com                       1
# rossgazette.com                     1
# classiccountry1070.com              1
# sfpublicpress.org                   1
# talkers.com                         1
# bibliocommons.com                   1
# matimunews.co.za                    1
# davisclipper.com                    1
# taiken.co                           1
# 933thedrive.com                     1
# surfsantamonica.com                 1
# insidescience.org                   1
#                                     1
# Length: 11240, dtype: int64

# %%
# save ke dalam CSV file
data_link_count.to_csv("Data\Sources.csv")
